# %% [markdown]
# # Categorical Plots

# %%
import seaborn as sns
# %matplotlib inline

import numpy as np

# %%
# load the built-in dataset named tips
tips = sns.load_dataset('tips')

# show the tips dataset
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Bar Plot

# %% [markdown]
# A bar plot is a general plot which allows you to aggreagate the categorical data based on some function. By default this aggregate function is the mean().
#
# It can be thought of as the visualization of a group by action.

# %%
# Choose the x axis to be a categorical column
sns.barplot(x='sex', y='total_bill', data=tips)

# %% [markdown]
# By default the above bar plot shows us the `mean` of the specified column `total_bill` categorised by the chosen categorical field `sex` but we can change the aggregate function based on our needs.

# %%
# changing the aggregate function to standard deviation
sns.barplot(x='sex', y='total_bill', data=tips, estimator=np.std)

# %% [markdown]
# ## Count Plot

# %% [markdown]
# A count plot is a special case of a bar plot where the estimator/aggregate function is specifically counting the number of occurences. Due to this we only need to specify the category

# %%
sns.countplot(data=tips, x='sex')

# %% [markdown]
# ## Bar Plot

# %% [markdown]
# The box plot is used to show the distribution of categorical data. It is sometimes also known as a box and whisker plot.

# %%
sns.boxplot(x='day', y='total_bill', data=tips)

# %% [markdown]
# In this case, we can visualize the `total_bill` category by the `day`. It can be observed that the total_bill tends to be higher on weekends as compared to week days.
#
# The box plots can be further split up into another categorical column by specifying the value for the `hue` parameter of the box plot

# %%
sns.boxplot(data=tips, x='total_bill', y='day', hue='smoker')

# %% [markdown]
# ## Violin Plot

# %% [markdown]
# A Violin Plot is used to visualise the distribution of the data and its probability density.

# %%
sns.violinplot(data=tips, x='day', y='total_bill')
# x is the variable with categorical data
# y is the variable with numerical data

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='sex')
# x is the variable with categorical data
# y is the variable with numeric data
# hue is the second variable with the categorical data

# %%
# We can have one half of the violin plot to be the probability density of one 'hue' and the other half to be the probability
# density of another hue

sns.violinplot(data=tips, x='day', y='total_bill', hue='sex', dodge=True)

# %% [markdown]
# ## Strip Plot

# %% [markdown]
# The strip plot is used to draw a scatter plot where one of the variable is categorical

# %%
sns.stripplot(data=tips, x='day', y='total_bill', jitter=False)

# %% [markdown]
# One issue with the above strip plot is that we cannot tell how many data points are stacked on the top of each other. This can be resolved by leaving the value of argument called `jitter` as `True`. Note that `jitter` helps us to separate these points from each other by adding random noise to the points.

# %%
sns.stripplot(data=tips, x='day', y='total_bill', jitter=True)

# %% [markdown]
# Just like the box plots and the violin plots, we can specify the value of the `hue` parameter in strip plots as well

# %%
sns.stripplot(data=tips, x='day', y='total_bill', hue='sex')
# jitter is set to True by default

# %% [markdown]
# After adding a value to the `hue` parameter, we can also split the strips of the strip plot from each other as per the value of `hue` parameter. For this we need to set the parameter `split` or `dodge` as True

# %%
sns.stripplot(data=tips, x='day', y='total_bill', hue='sex', dodge=True)

# %% [markdown]
# ## Swarm Plot

# %% [markdown]
# Some people like to combine the idea of a strip plot with that of a violin plot. This gives rise to a third plot known as the swarm plot. A swarm plot is very similar to a strip plot except that the points are adjusted so that they don't overlap

# %%
sns.swarmplot(data=tips, x='day', y='total_bill')

# %% [markdown]
# We can combine a violin plot and a swarm plot together.

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
sns.swarmplot(x='day',y='total_bill', data=tips, color='black')

# %% [markdown]
# ## Cat Plot

# %% [markdown]
# The `cat plot` is the generalization of all the categorical plots that we have looked at above. We can recreate all the catergorical plots mentioned above by specifying their name as the value to the `kind` parameter of the factor plot. The value of the `kind` parameter can be equal to `bar`, `strip`, `violin`, `box`, `swarm`, etc.

# %%
sns.catplot(data=tips, x='day', y='total_bill', hue='sex', kind='box')
